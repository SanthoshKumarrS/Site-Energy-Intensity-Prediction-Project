# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Site Energy Intensity Prediction </span>

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">⬇️ Importing Libraries</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
import plotly.io as pio
pio.renderers.default='notebook'
import dabl

from sklearn.impute import KNNImputer
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.decomposition import PCA
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, cross_val_score
import sklearn
import missingno as msno
import shap
import optuna
import joblib

import os
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">⬇️ Importing Data</span>

# %%
df_train = pd.read_csv('C:/Users/santh/Downloads/train_dataset.csv')

df_test = pd.read_csv('C:/Users/santh/Downloads/x_test.csv')

# %%
print(f'Train Dataset contains {df_train.shape[0]} rows and {df_train.shape[1]} columns')
print(f'Test Dataset contains {df_test.shape[0]} rows and {df_test.shape[1]} columns')
# Out:
# Train Dataset contains 75757 rows and 64 columns
# Test Dataset contains 9705 rows and 63 columns

# %%
df_train.head()
# Out:
#    Year_Factor State_Factor building_class  \
# 0            1      State_1     Commercial
# 1            1      State_1     Commercial
# 2            1      State_1     Commercial
# 3            1      State_1     Commercial
# 4            1      State_1     Commercial
#
#                                facility_type  floor_area  year_built  \
# 0               Grocery_store_or_food_market     61242.0      1942.0
# 1  Warehouse_Distribution_or_Shipping_center    274000.0      1955.0
# 2                       Retail_Enclosed_mall    280025.0      1951.0
# 3                  Education_Other_classroom     55325.0      1980.0
# 4                  Warehouse_Nonrefrigerated     66000.0      1985.0
#
#    energy_star_rating  ELEVATION  january_min_temp  january_avg_temp  ...  \
# 0                11.0        2.4                36              50.5  ...
# 1                45.0        1.8                36              50.5  ...
# ...

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">📊 Exploratory Data Analysis</span>

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     <font size='5pt'><b>Understanding features:</b></font>
#
# year_Factor: anonymized year in which the weather and energy usage factors were observed
#
# state_Factor: anonymized state in which the building is located
#
# building_class: building classification
#
# facility_type: building usage type
#
# floor_area: floor area (in square feet) of the building
#
# year_built: year in which the building was constructed
#
# energy_star_rating: the energy star rating of the building
#
# elevation: elevation of the building location
#
# january_min_temp: minimum temperature in January (in Fahrenheit) at the location of the building
#
# january_avg_temp: average temperature in January (in Fahrenheit) at the location of the building
#
# january_max_temp: maximum temperature in January (in Fahrenheit) at the location of the building
#
# [Similarly for all other months]
#
# cooling_degree_days: cooling degree day for a given day is the number of degrees where the daily average temperature
# exceeds 65 degrees Fahrenheit. Each month is summed to produce an annual total at the location of the building.
#
# heating_degree_days: heating degree day for a given day is the number of degrees where the daily average temperature   falls under 65 degrees Fahrenheit. Each month is summed to produce an annual total at the location of the building.
#
# precipitation_inches: annual precipitation in inches at the location of the building
#
# snowfall_inches: annual snowfall in inches at the location of the building
#
# snowdepth_inches: annual snow depth in inches at the location of the building
#
# avg_temp: average temperature over a year at the location of the building
#
# days_below_30F: total number of days below 30 degrees Fahrenheit at the location of the building
#
# days_below_20F: total number of days below 20 degrees Fahrenheit at the location of the building
#
# days_below_10F: total number of days below 10 degrees Fahrenheit at the location of the building
#
# days_below_0F: total number of days below 0 degrees Fahrenheit at the location of the building
#
# days_above_80F: total number of days above 80 degrees Fahrenheit at the location of the building
#
# days_above_90F: total number of days above 90 degrees Fahrenheit at the location of the building
#
# days_above_100F: total number of days above 100 degrees Fahrenheit at the location of the building
#
# days_above_110F: total number of days above 110 degrees Fahrenheit at the location of the building
#
# direction_max_wind_speed: wind direction for maximum wind speed at the location of the building. Given in 360-degree compass point directions (e.g. 360 = north, 180 = south, etc.).
#
# direction_peak_wind_speed: wind direction for peak wind gust speed at the location of the building. Given in 360-degree compass point directions (e.g. 360 = north, 180 = south, etc.).
#
# max_wind_speed: maximum wind speed at the location of the building
#
# days_with_fog: number of days with fog at the location of the building
#
# building_id: building id
# <br>
# <font size='5pt'><b>Target</b></font><br>
# site_eui: Site Energy Usage Intensity is the amount of heat and electricity consumed by a building as reflected in utility bills

# %%
df_train.columns
# Out:
# Index(['Year_Factor', 'State_Factor', 'building_class', 'facility_type',
#        'floor_area', 'year_built', 'energy_star_rating', 'ELEVATION',
#        'january_min_temp', 'january_avg_temp', 'january_max_temp',
#        'february_min_temp', 'february_avg_temp', 'february_max_temp',
#        'march_min_temp', 'march_avg_temp', 'march_max_temp', 'april_min_temp',
#        'april_avg_temp', 'april_max_temp', 'may_min_temp', 'may_avg_temp',
#        'may_max_temp', 'june_min_temp', 'june_avg_temp', 'june_max_temp',
#        'july_min_temp', 'july_avg_temp', 'july_max_temp', 'august_min_temp',
#        'august_avg_temp', 'august_max_temp', 'september_min_temp',
#        'september_avg_temp', 'september_max_temp', 'october_min_temp',
#        'october_avg_temp', 'october_max_temp', 'november_min_temp',
#        'november_avg_temp', 'november_max_temp', 'december_min_temp',
#        'december_avg_temp', 'december_max_temp', 'cooling_degree_days',
# ...

# %%
#converted all columns to lowecase :

df_train.columns = df_train.columns.str.lower().str.replace(' ','_')
df_test.columns = df_test.columns.str.lower().str.replace(' ','_')

# %%
#Combining the dataset for Visualisations :

df_test['site_eui'] = np.nan 
df_test['dataset'] = 'test'
df_train['dataset'] = 'train'


# train = commondf["dataset"]  == "train"

df_all = pd.concat([df_test,df_train], axis=0, ignore_index=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85462 entries, 0 to 85461
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year_factor                85462 non-null  int64
#  1   state_factor               85462 non-null  object
#  2   building_class             85462 non-null  object
#  3   facility_type              85462 non-null  object
#  4   floor_area                 85462 non-null  float64
#  5   year_built                 83533 non-null  float64
#  6   energy_star_rating         56499 non-null  float64
#  7   elevation                  85462 non-null  float64
#  8   january_min_temp           85462 non-null  int64
#  9   january_avg_temp           85462 non-null  float64
#  10  january_max_temp           85462 non-null  int64
#  11  february_min_temp          85462 non-null  int64
#  12  february_avg_temp          85462 non-null  float64
# ...

# %%
df_all.describe()
# Out:
#         year_factor    floor_area    year_built  energy_star_rating  \
# count  85462.000000  8.546200e+04  83533.000000        56499.000000
# mean       4.666671  1.656694e+05   1953.562616           61.531850
# std        1.617635  2.486965e+05     37.667384           28.595425
# min        1.000000  9.430000e+02      0.000000            0.000000
# 25%        3.000000  6.115500e+04   1927.000000           41.000000
# 50%        5.000000  9.041100e+04   1954.000000           68.000000
# 75%        6.000000  1.671960e+05   1981.000000           85.000000
# max        7.000000  6.385382e+06   2016.000000          100.000000
#
#           elevation  january_min_temp  january_avg_temp  january_max_temp  \
# count  85462.000000      85462.000000      85462.000000      85462.000000
# mean      58.325913         11.669502         34.579333         59.163230
# std      118.276994          9.801683          7.033171          5.425332
# ...

# %%
df_all.describe(include=['O']).T # to include categorical columns
# Out:
#                 count unique                        top   freq
# state_factor    85462      7                    State_6  50840
# building_class  85462      2                Residential  47656
# facility_type   85462     60  Multifamily_Uncategorized  41654
# dataset         85462      2                      train  75757

# %%
print(df_train.duplicated().sum())
print(df_test.duplicated().sum())
# Out:
# 0
# 0

# %%
# Checking for missing values

df_all.isna().sum()
# Out:
# year_factor           0
# state_factor          0
# building_class        0
# facility_type         0
# floor_area            0
#                   ...
# max_wind_speed    49657
# days_with_fog     54913
# id                    0
# site_eui           9705
# dataset               0
# Length: 65, dtype: int64

# %%
df_all.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 85457    False
# 85458    False
# 85459    False
# 85460    False
# 85461    False
# Length: 85462, dtype: bool

# %%
msno.bar(df_all) # visualizing missing values using missingno library
# Out:
# <AxesSubplot:>

# %%
# Function to calculate missing values and the columns :

def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(df_all)
# Out:
# Your selected dataframe has 65 columns.
# There are 7 columns that have missing values.
#                            Missing Values  % of Total Values
# days_with_fog                       54913               64.3
# direction_peak_wind_speed           50386               59.0
# direction_max_wind_speed            49657               58.1
# max_wind_speed                      49657               58.1
# energy_star_rating                  28963               33.9
# site_eui                             9705               11.4
# year_built                           1929                2.3

# %%
#unique value in Each columns:

for i in df_all.columns:
    print(f"Unique value in {i}:")
    print(df_all[i].nunique(),'\n')
# Out:
# Unique value in year_factor:
# 7
#
# Unique value in state_factor:
# 7
#
# Unique value in building_class:
# 2
#
# Unique value in facility_type:
# 60
#
# Unique value in floor_area:
# 20876
#
# Unique value in year_built:
# 183
#
# Unique value in energy_star_rating:
# 101
#
# Unique value in elevation:
# 215
#
# Unique value in january_min_temp:
# 59
#
# Unique value in january_avg_temp:
# 173
#
# Unique value in january_max_temp:
# 49
#
# Unique value in february_min_temp:
# 53
#
# Unique value in february_avg_temp:
# 176
#
# Unique value in february_max_temp:
# 43
#
# Unique value in march_min_temp:
# 55
#
# Unique value in march_avg_temp:
# 173
#
# Unique value in march_max_temp:
# 42
#
# Unique value in april_min_temp:
# 36
#
# Unique value in april_avg_temp:
# 171
#
# Unique value in april_max_temp:
# 35
#
# Unique value in may_min_temp:
# 35
#
# Unique value in may_avg_temp:
# 172
#
# Unique value in may_max_temp:
# 39
#
# Unique value in june_min_temp:
# 36
#
# ...

# %%
for i in df_all.columns:
    print(f"Unique value in {i}:")
    print(df_all[i].unique(),'\n')
# Out:
# Unique value in year_factor:
# [7 1 2 3 4 5 6]
#
# Unique value in state_factor:
# ['State_1' 'State_2' 'State_4' 'State_8' 'State_11' 'State_10' 'State_6']
#
# Unique value in building_class:
# ['Commercial' 'Residential']
#
# Unique value in facility_type:
# ['Grocery_store_or_food_market' 'Public_Assembly_Social_meeting'
#  'Mixed_Use_Predominantly_Commercial' 'Religious_worship'
#  'Office_Medical_non_diagnostic'
#  'Warehouse_Distribution_or_Shipping_center'
#  'Service_Vehicle_service_repair_shop' 'Warehouse_Selfstorage'
#  'Commercial_Other' 'Retail_Enclosed_mall' 'Public_Assembly_Movie_Theater'
#  'Retail_Strip_shopping_mall' 'Retail_Uncategorized'
#  'Education_Other_classroom' 'Office_Uncategorized' 'Food_Sales'
#  'Warehouse_Nonrefrigerated' 'Industrial' 'Warehouse_Refrigerated'
#  'Education_Uncategorized' 'Data_Center' 'Office_Bank_or_other_financial'
#  'Lodging_Hotel' 'Food_Service_Uncategorized' 'Parking_Garage'
# ...

# %%
#Since there are many Columns grouping them into categories for Easirer Exploration :

target = ['site_eui']

categoriacal_cols = ['state_factor','building_class','facility_type']

month_cols = ['january_min_temp', 'january_avg_temp', 'january_max_temp',
       'february_min_temp', 'february_avg_temp', 'february_max_temp',
       'march_min_temp', 'march_avg_temp', 'march_max_temp', 'april_min_temp',
       'april_avg_temp', 'april_max_temp', 'may_min_temp', 'may_avg_temp',
       'may_max_temp', 'june_min_temp', 'june_avg_temp', 'june_max_temp',
       'july_min_temp', 'july_avg_temp', 'july_max_temp', 'august_min_temp',
       'august_avg_temp', 'august_max_temp', 'september_min_temp',
       'september_avg_temp', 'september_max_temp', 'october_min_temp',
       'october_avg_temp', 'october_max_temp', 'november_min_temp',
       'november_avg_temp', 'november_max_temp', 'december_min_temp',
       'december_avg_temp', 'december_max_temp']

climate_cols = ['cooling_degree_days',
       'heating_degree_days', 'precipitation_inches', 'snowfall_inches',
       'snowdepth_inches', 'avg_temp', 'days_below_30f', 'days_below_20f',
       'days_below_10f', 'days_below_0f', 'days_above_80f', 'days_above_90f',
       'days_above_100f', 'days_above_110f', 'direction_max_wind_speed',
       'direction_peak_wind_speed', 'max_wind_speed', 'days_with_fog']

building_cols = ['floor_area', 'year_built', 'energy_star_rating', 'elevation']

# %%
#Checking for the distribution of Target Variable :

sns.histplot(df_train[target], bins = 50)
plt.title('Distribution of Target Variable')
plt.show()

# %%
for columns in categoriacal_cols:
    if columns == 'facility_type':
        break
    plt.figure(figsize=(4,4))
    sns.countplot(x=columns, data=df_all)
    plt.xticks(rotation=25)

# %%
plt.figure(figsize=(16,6))
sns.stripplot(x='facility_type', y='site_eui', data=df_all)
plt.xticks(rotation=90)
plt.show()

# %%
# Pair-wise Scatter Plots of Columns related to Buildings:

pp = sns.pairplot(df_all[building_cols], size=1.8, aspect=1.8,
                  plot_kws=dict(edgecolor="k", linewidth=0.5),
                  diag_kind="kde", diag_kws=dict(shade=True))

fig = pp.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Site Attributes Pairwise Plots', fontsize=14)

# %%
# Visualizing 3-D numeric data with Scatter Plots
# length, breadth and depth

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = df_all['floor_area']
ys = df_all['elevation']
zs = df_all['energy_star_rating']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('floor_area')
ax.set_ylabel('elevation')
ax.set_zlabel('energy_star_rating')
# Out:
# Text(0.5, 0, 'energy_star_rating')

# %%
fig, axs = plt.subplots(ncols=3, nrows=12, figsize=(12, 24))
plt.subplots_adjust(wspace=0.5, hspace=1.0)

print('Analysis of Monthly Columns :')

for i, col in enumerate(month_cols):
    sns.histplot(df_all[col], color='green', bins=20, ax=axs[i // 3, i % 3])    
plt.show()
# Out:
# Analysis of Monthly Columns :

# %%
fig, axs = plt.subplots(ncols=3, nrows=6, figsize=(12, 12))
plt.subplots_adjust(wspace=0.5, hspace=1.0)

print('Analysis of Climate Columns :')

for i, col in enumerate(climate_cols):
    sns.histplot(df_all[col], color='blue', ax=axs[i // 3, i % 3],kde=True,bins=20)    

plt.show()
# Out:
# Analysis of Climate Columns :

# %% [markdown]
# **Observations :**
#
# * `elevation` column has relation with target column
# * There's no significant correlation between dependent columns and target column
# * Categorical variables such as `State_Factor`, `building_class` and `facility_type` might have some correlation with EUI
# * Other variables aren't much co-related with the Target Variable

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">⚙️ Preprocessing</span>

# %% [markdown]
# ### Encoding :

# %%
df_copy = df_all.copy(deep=True)

# %%
object_columns = ['state_factor', 'building_class', 'facility_type']

# %%
#Let us encode categorical features using Ordinal Encoding :

encoder = OrdinalEncoder()

df_copy[object_columns] = encoder.fit_transform(df_copy[object_columns])

df_copy.head()
# Out:
#    year_factor  state_factor  building_class  facility_type  floor_area  \
# 0            7           0.0             0.0           13.0     28484.0
# 1            7           0.0             0.0           13.0     21906.0
# 2            7           0.0             0.0           13.0     16138.0
# 3            7           0.0             0.0           13.0     97422.0
# 4            7           0.0             0.0           13.0     61242.0
#
#    year_built  energy_star_rating  elevation  january_min_temp  \
# 0      1994.0                37.0        2.4                38
# 1      1961.0                55.0       45.7                38
# 2      1950.0                 1.0       59.1                38
# 3      1971.0                34.0       35.4                38
# 4      1942.0                35.0        1.8                38
#
#    january_avg_temp  ...  days_above_90f  days_above_100f  days_above_110f  \
# ...

# %% [markdown]
# ### Handling Missing Values :

# %%
missing_values_table(df_copy)
# Out:
# Your selected dataframe has 65 columns.
# There are 7 columns that have missing values.
#                            Missing Values  % of Total Values
# days_with_fog                       54913               64.3
# direction_peak_wind_speed           50386               59.0
# direction_max_wind_speed            49657               58.1
# max_wind_speed                      49657               58.1
# energy_star_rating                  28963               33.9
# site_eui                             9705               11.4
# year_built                           1929                2.3

# %%
#Let's fill the missing Values with Knn Imputer as there are large chunks of data missing and in a Random way :

missing_val_cols = ['days_with_fog','direction_peak_wind_speed','direction_max_wind_speed','max_wind_speed','energy_star_rating','year_built']

knn_imputer = KNNImputer(n_neighbors=7,weights="uniform")
knn_imputer.fit(df_copy[missing_val_cols])

df_copy[missing_val_cols] = knn_imputer.transform(df_copy[missing_val_cols])

# %%
#Let's check after Imputing :

missing_values_table(df_copy)
# Out:
# Your selected dataframe has 65 columns.
# There are 1 columns that have missing values.
#           Missing Values  % of Total Values
# site_eui            9705               11.4

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Feature Engineering</span>

# %%
df_copy.columns
# Out:
# Index(['year_factor', 'state_factor', 'building_class', 'facility_type',
#        'floor_area', 'year_built', 'energy_star_rating', 'elevation',
#        'january_min_temp', 'january_avg_temp', 'january_max_temp',
#        'february_min_temp', 'february_avg_temp', 'february_max_temp',
#        'march_min_temp', 'march_avg_temp', 'march_max_temp', 'april_min_temp',
#        'april_avg_temp', 'april_max_temp', 'may_min_temp', 'may_avg_temp',
#        'may_max_temp', 'june_min_temp', 'june_avg_temp', 'june_max_temp',
#        'july_min_temp', 'july_avg_temp', 'july_max_temp', 'august_min_temp',
#        'august_avg_temp', 'august_max_temp', 'september_min_temp',
#        'september_avg_temp', 'september_max_temp', 'october_min_temp',
#        'october_avg_temp', 'october_max_temp', 'november_min_temp',
#        'november_avg_temp', 'november_max_temp', 'december_min_temp',
#        'december_avg_temp', 'december_max_temp', 'cooling_degree_days',
# ...

# %%
# Summetion of seasonal (i.e. winter and summer) columns  to reduce columns and MC
df_copy['avg_min_temp_winter'] = (df_copy['january_min_temp'] + df_copy['february_min_temp'] + df_copy['march_min_temp'] + 
                               df_copy['april_min_temp'] + df_copy['october_min_temp'] + df_copy['november_min_temp'] +
                               df_copy['december_min_temp'])/7

df_copy['avg_max_temp_winter'] = (df_copy['january_max_temp'] + df_copy['february_max_temp'] + df_copy['march_max_temp'] + 
                               df_copy['april_max_temp'] + df_copy['october_max_temp'] + df_copy['november_max_temp'] +
                               df_copy['december_max_temp'])/7

df_copy['avg_temp_winter'] = (df_copy['january_avg_temp'] + df_copy['february_avg_temp'] + df_copy['march_avg_temp'] + 
                           df_copy['april_avg_temp'] + df_copy['october_avg_temp'] + df_copy['november_avg_temp'] +
                           df_copy['december_avg_temp'])/7

# %%
df_copy['avg_min_temp_summer'] = (df_copy['may_min_temp'] + df_copy['june_min_temp'] + df_copy['july_min_temp'] +
                               df_copy['august_min_temp'] + df_copy['september_min_temp'])/5 
df_copy['avg_max_temp_summer'] = (df_copy['may_max_temp'] + df_copy['june_max_temp'] + df_copy['july_max_temp'] +
                               df_copy['august_max_temp'] + df_copy['september_max_temp'])/5
df_copy['avg_temp_summer'] = (df_copy['may_avg_temp'] + df_copy['june_avg_temp'] + df_copy['july_avg_temp'] +
                           df_copy['august_avg_temp'] + df_copy['september_avg_temp'])/5

# %%
df_copy['avg_days_below30f'] = (df_copy['days_below_30f'] + df_copy['days_below_20f'] + df_copy['days_below_10f'] +
                                df_copy['days_below_0f'])/4

# %%
df_copy.shape
# Out:
# (85462, 72)

# %%
df_all.columns
# Out:
# Index(['year_factor', 'state_factor', 'building_class', 'facility_type',
#        'floor_area', 'year_built', 'energy_star_rating', 'elevation',
#        'january_min_temp', 'january_avg_temp', 'january_max_temp',
#        'february_min_temp', 'february_avg_temp', 'february_max_temp',
#        'march_min_temp', 'march_avg_temp', 'march_max_temp', 'april_min_temp',
#        'april_avg_temp', 'april_max_temp', 'may_min_temp', 'may_avg_temp',
#        'may_max_temp', 'june_min_temp', 'june_avg_temp', 'june_max_temp',
#        'july_min_temp', 'july_avg_temp', 'july_max_temp', 'august_min_temp',
#        'august_avg_temp', 'august_max_temp', 'september_min_temp',
#        'september_avg_temp', 'september_max_temp', 'october_min_temp',
#        'october_avg_temp', 'october_max_temp', 'november_min_temp',
#        'november_avg_temp', 'november_max_temp', 'december_min_temp',
#        'december_avg_temp', 'december_max_temp', 'cooling_degree_days',
# ...

# %%
#Let's remove the unwanted columns:

r_columns = ['days_below_30f','days_below_20f','days_below_10f','days_below_0f','id']

df = df_copy.drop(columns=r_columns,axis=1)

# %% [markdown]
# ### Checking & Treating Multi-Collinearity :

# %%
# Remove the response variable from the data
variance = df.drop(['site_eui','state_factor','building_class','facility_type','dataset'], axis=1)

# Compute the variance inflation factor (VIF) for each predictor variable
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(variance.values, i) for i in range(variance.shape[1])]
vif["features"] = variance.columns

# Print the results
print(vif.sort_values)
# Out:
# <bound method DataFrame.sort_values of      VIF Factor             features
# 0    649.667622          year_factor
# 1      1.550204           floor_area
# 2   2988.673384           year_built
# 3      7.667143   energy_star_rating
# 4      2.442479            elevation
# ..          ...                  ...
# 57          inf      avg_temp_winter
# 58          inf  avg_min_temp_summer
# 59          inf  avg_max_temp_summer
# 60          inf      avg_temp_summer
# 61   803.366919    avg_days_below30f
#
# [62 rows x 2 columns]>

# %% [markdown]
# We could see there aren't considerable amount of columns with higher VIF,So we can rule out Multi-collinearity Factor

# %%
train = df[df['dataset']=='train']
test = df[df['dataset']=='test']

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

target = train['site_eui'] #y_train

train = train.drop(['dataset', 'site_eui'], axis=1) #X_train
test = test.drop(['dataset', 'site_eui'], axis=1) #X_test

# %%
# train-test Split:

y_test = pd.read_csv('C:/Users/santh/Downloads/y_test.csv')

X_train = train
X_test = test
y_train = target
y_test = y_test['site_eui']
print('Train: ', X_train.shape)
print('Test:', X_test.shape)
print('Samples: ', y_train.shape)
print('Targets: ', y_test.shape)
# Out:
# Train:  (75757, 65)
# Test: (9705, 65)
# Samples:  (75757,)
# Targets:  (9705,)

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">🧰 Baseline Modelling</span>

# %%
#Base Linear Regression Model:

lr_model = LinearRegression()
lr_model.fit(X_train,y_train)
y_pred = lr_model.predict(X_test)

rmse_lr_model = np.sqrt(mean_squared_error(y_test, y_pred))

print(f'RMSE for Linear Regression = {rmse_lr_model}')
# Out:
# RMSE for Linear Regression = 54.56794534973222

# %%
#XgBoost Regressor:

xgb = XGBRegressor(n_estimators=500, reg_alpha=0.01, n_jobs=-1)
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)

rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred))

print(f'RMSE for XGB = {rmse_xgb}')
# Out:
# RMSE for XGB = 42.989898787418035

# %%
#Random Forest :

rf = RandomForestRegressor(random_state=1, max_depth = 15, min_samples_split= 2)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred))

print(f'RMSE for Random Forest = {rmse_rf}')
# Out:
# RMSE for Random Forest = 40.43455278073934

# %%
#Catboost :

# get discrete end categorical features colums indexes 
# needed later for the cat bosst model
cats_discrete_idx = np.where(train.dtypes != 'float64')[0]

catb = CatBoostRegressor(iterations=500,
                         learning_rate=0.02,
                         depth=12,
                         eval_metric='RMSE',
                         random_seed = 23,
                         bagging_temperature = 0.2,
                         od_type='Iter',
                         metric_period = 75,
                         od_wait=100
                        )

catb.fit(X_train, y_train,
                 eval_set=(X_test,y_test),
                 cat_features=cats_discrete_idx,
                 use_best_model=True,
                 verbose=True)

y_pred = catb.predict(X_test)


rmse_catb = np.sqrt(mean_squared_error(y_test, y_pred))

print(f'RMSE for CatBoost = {rmse_catb}')
# Out:
# ...
# 0:	learn: 57.8452786	test: 60.6758941	best: 60.6758941 (0)	total: 499ms	remaining: 4m 9s
# 75:	learn: 45.5043008	test: 45.8377568	best: 45.8377568 (75)	total: 36.7s	remaining: 3m 24s
# 150:	learn: 42.7193053	test: 43.9029976	best: 43.6637017 (140)	total: 1m 16s	remaining: 2m 57s
# 225:	learn: 41.5302207	test: 43.2651082	best: 43.2207363 (222)	total: 1m 55s	remaining: 2m 20s
# 300:	learn: 40.8563096	test: 42.9548942	best: 42.9430088 (293)	total: 2m 34s	remaining: 1m 42s
# 375:	learn: 40.2035835	test: 42.5980147	best: 42.5980147 (375)	total: 3m 14s	remaining: 1m 4s
# 450:	learn: 39.6739862	test: 42.4665702	best: 42.4665702 (450)	total: 3m 54s	remaining: 25.5s
# 499:	learn: 39.2962519	test: 42.4992726	best: 42.4224482 (463)	total: 4m 22s	remaining: 0us
#
# bestTest = 42.42244816
# bestIteration = 463
#
# Shrink model to first 464 iterations.
# RMSE for CatBoost = 42.42244820352612

# %%
#Lasso Regression :

lasso = Lasso()
lasso.fit(X_train, y_train)
y_pred = lasso.predict(X_test)

rmse_lasso = np.sqrt(mean_squared_error(y_test, y_pred))

print(f'RMSE for SVM = {rmse_lasso}')
# Out:
# RMSE for SVM = 54.94918973120075

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Basic Models Evaluation</span>

# %%
error_rec = {
    "Linear Regression": {
        "rmse": rmse_lr_model,
    },
    "catboost": {
        "rmse": rmse_catb,
    },
    "randomforest": {
        "rmse": rmse_rf,
    },
    "xgboost": {
        "rmse": rmse_xgb,
    },
    "lasso": {
        "rmse": rmse_lasso,
    },
}
pd.DataFrame(error_rec).plot(kind="bar", 
             color=[
                 sns.color_palette("pastel")[0], 
                 sns.color_palette("pastel")[1], 
                 sns.color_palette("pastel")[2], 
                 sns.color_palette("pastel")[3],
                 sns.color_palette("pastel")[4]]);

plt.title("Comparison of RMSE scores of Basic Models:")
plt.show()

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Hyperparameter Tuning using Optuna :</span>

# %%
# cross validating training data
kfolds = KFold(n_splits=3, shuffle=True, random_state=42)

# Objective function
def random_forest_objective(trial, data=X_train, target=y_train):
    # Dictionary to store best parameters
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 5, 20),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "max_features": trial.suggest_float("max_features", 0.01, 0.95)
    }
     
    model = RandomForestRegressor(**param)
    
    # Setting random seed and kfolds for cross-validation
    kfolds = KFold(n_splits=10, shuffle=True, random_state=42)
    
    scores = cross_val_score(model, data, target, cv=kfolds, scoring="neg_root_mean_squared_error")
    return scores.mean()

# %%
def tuner(objective, n=5, direction='minimize'): 
    # Create Study object
    study = optuna.create_study(direction="minimize")

    # Optimize the study
    study.optimize(objective, n_trials=n)

    # Print the result
    best_params = study.best_params
    best_score = study.best_value
    print(f"Best score: {best_score}")
    print(f"Optimized parameters: {best_params}\n")
    print("<<<<<<<<<< Tuning complete... >>>>>>>>>>")
    
    # Return best parameters for the model
    return best_params, best_score

# %%
rf_param, rf_score = tuner(random_forest_objective,1)
rf_tuned_model = RandomForestRegressor(**rf_param)
# Out:
# [I 2023-05-20 01:45:48,023] A new study created in memory with name: no-name-f820d718-b82d-4a65-b3d4-579a09aebd11
# [I 2023-05-20 01:55:03,848] Trial 0 finished with value: -43.48680515847128 and parameters: {'n_estimators': 363, 'max_depth': 18, 'min_samples_split': 7, 'max_features': 0.2672092556313876}. Best is trial 0 with value: -43.48680515847128.
# Best score: -43.48680515847128
# Optimized parameters: {'n_estimators': 363, 'max_depth': 18, 'min_samples_split': 7, 'max_features': 0.2672092556313876}
#
# <<<<<<<<<< Tuning complete... >>>>>>>>>>

# %%
#Evaluation of Tuned Model :

rf_tuned_model.fit(X_train,y_train)
y_pred = rf_tuned_model.predict(X_test)

rmse_tuned_rf = np.sqrt(mean_squared_error(y_test, y_pred))

print(f'RMSE for Tuned Random Forest Model = {rmse_tuned_rf}')
# Out:
# RMSE for Tuned Random Forest Model = 52.12414091690947

# %%
y_hat_tuned = rf_tuned_model.predict(X_test)

plt.figure(figsize = (7,5))
sns.distplot(y_test - y_hat_tuned)
plt.title("Error Rate Distribution");
plt.ylabel("error")
plt.xlabel("iteration")
# Out:
# Text(0.5, 0, 'iteration')

# %%
rf_tuned_model.feature_importances_
# Out:
# array([1.61396373e-03, 5.54649303e-03, 2.06943723e-02, 2.09477175e-01,
#        1.41906199e-01, 8.09768631e-02, 2.88203533e-01, 2.13028681e-02,
#        4.55106404e-03, 1.17177614e-02, 1.70518526e-03, 2.64860802e-03,
#        9.02460152e-03, 2.16904344e-03, 2.91456679e-03, 1.64011204e-03,
#        1.84077866e-03, 1.91471291e-03, 2.73044108e-03, 1.21669055e-03,
#        1.91877616e-03, 2.25647249e-03, 1.50153452e-03, 1.73612084e-03,
#        2.40723036e-03, 1.59072866e-03, 1.71425779e-03, 1.70689412e-03,
#        1.44411238e-03, 1.08005201e-03, 2.20338733e-03, 1.73695990e-03,
#        1.86827443e-03, 2.07273845e-03, 1.98628970e-03, 1.72739754e-03,
#        1.98793517e-03, 1.59425742e-03, 1.50869558e-03, 1.77670410e-03,
#        2.52674271e-03, 1.37353267e-03, 1.40853549e-03, 1.99332750e-03,
#        1.75184865e-03, 8.63144254e-03, 2.16169617e-03, 5.34618358e-03,
#        4.00018623e-03, 1.34450065e-03, 2.40810520e-03, 1.81188927e-03,
# ...

# %%
df_importance = pd.DataFrame()
df_importance['Features'] = X_train.columns
df_importance['Importance'] = rf_tuned_model.feature_importances_

# Get the top 10 rows of the DataFrame, sorted by the Importance column
top10_features = df_importance.nlargest(10, 'Importance')

# Plot the bar plot
plt.figure(figsize=(6, 6))
sns.barplot(data = top10_features, y='Features', x='Importance');

# %%
top_features = list(df_importance.sort_values("Importance", ascending=False)['Features'].head(10).values)
top_features
# Out:
# ['energy_star_rating',
#  'facility_type',
#  'floor_area',
#  'year_built',
#  'days_with_fog',
#  'elevation',
#  'building_class',
#  'direction_peak_wind_speed',
#  'max_wind_speed',
#  'direction_max_wind_speed']

# %%
# Top Features train-test Split:

y_test = pd.read_csv('C:/Users/santh/Downloads/y_test.csv')

X_train_new = train[top_features]
X_test_new = test[top_features]
y_train_new = target
y_test_new = y_test['site_eui']
print('Train: ', X_train_new.shape)
print('Test:', X_test_new.shape)
print('Samples: ', y_train_new.shape)
print('Targets: ', y_test_new.shape)
# Out:
# Train:  (75757, 10)
# Test: (9705, 10)
# Samples:  (75757,)
# Targets:  (9705,)

# %%
X_train_new.head()
# Out:
#    energy_star_rating  facility_type  floor_area  year_built  days_with_fog  \
# 0                11.0           13.0     61242.0      1942.0      83.714286
# 1                45.0           55.0    274000.0      1955.0      12.000000
# 2                97.0           48.0    280025.0      1951.0      12.000000
# 3                46.0            6.0     55325.0      1980.0      12.000000
# 4               100.0           56.0     66000.0      1985.0     103.285714
#
#    elevation  building_class  direction_peak_wind_speed  max_wind_speed  \
# 0        2.4             0.0                        1.0             1.0
# 1        1.8             0.0                        1.0             1.0
# 2        1.8             0.0                        1.0             1.0
# 3        1.8             0.0                        1.0             1.0
# 4        2.4             0.0                        1.0             1.0
#
#    direction_max_wind_speed
# 0                       1.0
# ...

# %%
df_train[top_features].dtypes
# Out:
# energy_star_rating           float64
# facility_type                 object
# floor_area                   float64
# year_built                   float64
# days_with_fog                float64
# elevation                    float64
# building_class                object
# direction_peak_wind_speed    float64
# max_wind_speed               float64
# direction_max_wind_speed     float64
# dtype: object

# %%
rf_tuned_model.fit(X_train_new, y_train_new)

y_pred_new = rf_tuned_model.predict(X_test_new)

rmse_final = np.sqrt(mean_squared_error(y_test_new, y_pred_new))
print(f'RMSE for Final Model = {rmse_final}')
# Out:
# RMSE for Final Model = 40.601364632817

# %%
y_test_new.head()
# Out:
# 0    166.588554
# 1    259.381565
# 2    158.537090
# 3    261.441520
# 4    242.967711
# Name: site_eui, dtype: float64

# %%
test = X_test_new.loc[4]
test = test.values.reshape(1,-1)
test
# Out:
# array([[3.5000e+01, 1.3000e+01, 6.1242e+04, 1.9420e+03, 1.2600e+02,
#         1.8000e+00, 0.0000e+00, 3.3000e+02, 2.2800e+01, 3.4000e+02]])

# %%
pred = rf_tuned_model.predict(test)

print(f"The predicted EUI is:  {pred[0]}")
# Out:
# The predicted EUI is:  177.42525687792582

# %%
#Saving Model :

with open('random_forest.joblib', 'wb') as f:
    joblib.dump(rf_tuned_model, f, compress=1)

# %%
#Loading the Model :

with open('random_forest.joblib', 'rb') as f:
        rf_loaded = joblib.load(f)
        
prediction = rf_loaded.predict(X_test_new)

rmse_loaded = np.sqrt(mean_squared_error(y_test_new,prediction))

print(rmse_loaded)
# Out:
# 40.601364632817

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Explainable AI</span>

# %%
shap.initjs()
sample_data = X_train_new.sample(100)
explainer = shap.TreeExplainer(rf_tuned_model)
shap_values = explainer.shap_values(sample_data)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap.summary_plot(shap_values, sample_data, plot_type="bar",plot_size=[4,4])

# %%
shap.summary_plot(shap_values, sample_data,plot_size=[4,4])

# %%
shap.dependence_plot('energy_star_rating', shap_values, sample_data)

# %%
shap.decision_plot(shap.TreeExplainer(rf_tuned_model).expected_value[0], 
                   shap_values[50:100], 
                   feature_names=sample_data.columns.tolist()
                  )
plt.gcf().set_size_inches(4,4)
plt.show()

# %%
limit = 500
shap.plots.heatmap(shap.TreeExplainer(rf_tuned_model, data=sample_data)(sample_data[:limit]), max_display=15)
# Out:
#  93%|=================== | 93/100 [00:13<00:00]

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Conclusions :</span>

# %% [markdown]
# * Tuned Model did not increase  RMSE score but might avoid Overfitting on Training Data,
# * Explainable AI using SHAP depicts that `energy star rating` and `floor area` are among the top most important features among all the features available in dataset.
# * Tuned Fandom Forest Model gave RMSE score of 45 which is higher than Base Model score of 40.
